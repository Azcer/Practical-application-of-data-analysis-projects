# %% [markdown]
# # 项目：北美餐馆综合数据

# %% [markdown]
# ## 数据简介

# %% [markdown]
# ---
# Topic:
#     - 饮食
# ,    - 商业金融
# ,    - 日常生活
#
# Field:
#     - 数据挖掘
# ,    - 回归
#
# Ext:
#     - .csv
#
# DatasetUsage:
#     - 88092
# ---
#
# ### **背景描述**
# 本数据集收集了1500 个北美餐馆综合数据信息，包括餐厅位置、提供的菜品、餐厅评分等。
#
# ![Image Name](https://cdn.kesci.com/upload/image/s9av02ycpj.png?imageView2/0/w/640/h/640)
#
# ### **数据说明**
# | 字段                    | 说明                                       |
# |-------------------------|--------------------------------------------|
# | name                    | 餐厅名称。                                  |
# | city                    | 餐厅所在城市。                             |
# | state                   | 餐厅所在的州或省份。                        |
# | zipcode                 | 餐厅的邮政编码。                           |
# | country                 | 餐厅所在国家（美国或加拿大）。             |
# | cuisines                | 餐厅提供的菜系类型。                       |
# | pickup_enabled          | 表示是否提供取餐服务（是或否）。           |
# | delivery_enabled        | 表示是否提供外卖服务（是或否）。           |
# | weighted_rating_value   | 餐厅的平均评分，范围从0到5。             |
# | aggregated_rating_count | 餐厅收到的总评分数量。                     |
#
# ### **数据来源**
# https://www.kaggle.com/datasets/saketk511/1500-north-american-resturants
#
# ### **问题描述**
# 餐馆数量分布
# 餐馆评分分布
# 不同菜系类型的比较
# 餐馆服务选项分析
# 顾客评分与评价数量的关系

# %% [markdown]
# ## 读取数据

# %% [markdown]
# 导入数据分析所需要的库，并通过Pandas的`read_csv`函数，将原始数据文件"North America Restaurants.csv"里的数据内容，解析为DataFrame，并赋值给变量`original_data`。

# %%
import pandas as pd

# %%
original_data = pd.read_csv("North America Restaurants.csv")
original_data.head()
# Out:
#                              name         city state  zipcode country  \
# 0                     Burger King    Manitowoc    WI    54220      US
# 1                    Petro-Canada      Airdrie    AB      T4A      CA
# 2                        Boba Bae  Ashwaubenon    WI    54304      US
# 3            1001 Nights Shawarma    Kitchener    ON      N2C      CA
# 4  Chirpyhut Fried Chicken (JlgJ)     Richmond    BC  V6X 2B8      CA
#
#                                                                                                                                                                                                   cuisines  \
# 0                                                                                                                                    American, Burger, Burgers, Family Meals, Fast Food, Subs & Sandwiches
# 1  Ben & Jerry's, Café/Thé, Coffee/Tea, Convenience, Cool Treats, Crème Glacée, Crèmerie, Dessert, Desserts, Drinks, Dépanneur, Everyday Essentials, Food & Drinks, Fringales Nocturnes, Grocery, Gâter...
# 2                                                                                                                                                  American, Asian Food, Bubble Tea, Coffee & Tea, Dessert
# 3  Beau, Bon, Local, Chicken, Dessert, Desserts, Global Diversity Month, Lebanese, Local Goods, Mediterranean, Middle East, Middle Eastern, Mois Mondial De La Diversité, Moyen-Oriental, Must-Eat Rest...
# 4  Ailes, Allergy Friendly, American, Beau, Bon, Local, Burgers, Chicken, Fait-Maison, Fast Food, Group Friendly, Hamburgers, Homemade, Hot Deal Summer, Local Goods, Offers, Offres, Poulet, Promos D'...
#
#    pickup_enabled  delivery_enabled  weighted_rating_value  \
# 0            True              True                    2.4
# 1            True              True                    4.1
# 2            True              True                    4.0
# 3            True              True                    4.6
# 4            True              True                    4.6
#
#    aggregated_rating_count
# 0                       42
# 1                        1
# 2                       88
# 3                     1077
# 4                       30

# %% [markdown]
# ## 评估数据

# %% [markdown]
# 在这个在这一部分，我将对在上一部分建立的`original_data`这个DataFrame所包含的数据进行评估。
#
# 评估主要从两个方面进行：结构和内容，即整齐度和干净度。数据的结构性问题指不符合“每列是一个变量，每行是一个观察值，每个单元格是一个值”这三个标准，数据的内容性问题包括存在丢失数据、重复数据、无效数据等。

# %% [markdown]
# ### 评估整齐度

# %%
original_data.sample(10)
# Out:
#                       name         city state  zipcode country  \
# 960              Starbucks    Kitchener    ON  N2P 2J5      CA
# 1037       Cluck U Chicken      Hoboken    NJ     7030      US
# 858   Endivine Grill & Bar  Bowmanville    ON  L1C 1N4      CA
# 719         Route 66 Pizza       Orting    WA    98360      US
# 385             McDonald's       Conway    AR    72034      US
# 486       Jalebi Junction🌀      Toronto    ON  M6J 1E3      CA
# 686                Krystal    Pensacola    FL    32504      US
# 388            Pizza Ranch  Sun Prairie    WI    53590      US
# 773            Burger King   Eau Claire    WI    54703      US
# 1317   Ennio's Pasta House     Waterloo    ON  N2J 4G8      CA
#
#                                                                                                                                                                                                      cuisines  \
# 960   Bakery, Breakfast &Amp; Brunch, Breakfast And Brunch, Cafe, Cold Coffees, Cold Drinks, Frappuccino Blended Beverages, Frappuccino® Blended Beverages, Hot Breakfast, Hot Coffees, Hot Drinks, Hot Te...
# 1037                                                                                                            American, Bowls, Chicken, Dinner, Hamburgers, Late Night, Lunch, Lunch Specials, Wings, Wraps
# 858   Allergy Friendly, Breakfast & Brunch, Burgers, Canadian, Canadien, Déjeuner Et Brunch, Dîner, European, Healthy, Lunch, Modern European, Salads, Sandwiches & Subs, Sandwichs Et Sous-Marins, Santé,...
# 719                                                                                                                 American, Dessert, Fast Food, Healthy Pizza, Lunch, Pizza, Thin Crust Pizza, Veggie Pizza
# 385                                                                                                American, Breakfast, Burger, Burgers, Cheeseburger, Chicken, Coffee, Desserts, Fast Food, Hamburger, Salad
# 486                                                                                                                                                                              Desserts, Indian, Vegetarian
# 686                                                                                                                                                                              American, Burgers, Fast Food
# 388                                                                                                                                                             Chicken, Dessert, Fried Chicken, Pizza, Wings
# 773                                                                                                                                         American, American Food, Burger, Burgers, Family Meals, Fast Food
# 1317  Beau, Bon, Local, Chicken, Comfort Food, Fait-Maison, Fruits De Mer, Group Friendly, Homemade, Italian, Italien, Local Goods, Local Legends, Légendes Locales, Noodle Shop, Nouilles, Pasta, Pizza, ...
#
#       pickup_enabled  delivery_enabled  weighted_rating_value  \
# 960            False              True                    4.2
# 1037            True              True                    2.0
# 858             True              True                    4.7
# 719             True              True                    2.0
# 385            False              True                    3.8
# 486             True              True                    2.2
# 686             True              True                    3.6
# 388             True              True                    2.9
# 773             True              True                    2.6
# 1317            True              True                    4.7
#
#       aggregated_rating_count
# 960                        34
# 1037                       58
# 858                        16
# 719                         1
# 385                        20
# 486                        19
# 686                        56
# 388                        11
# 773                         6
# 1317                      134

# %% [markdown]
# 从抽样的10行数据数据来看，数据符合“每列是一个变量，每行是一个观察值”但是`cuisines`列有多个值，具体来看每行是关于某餐馆的基本信息，每列是点评相关的各个变量。

# %% [markdown]
# ### 评估数据干净度

# %%
original_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   name                     1500 non-null   object
#  1   city                     1500 non-null   object
#  2   state                    1500 non-null   object
#  3   zipcode                  1500 non-null   object
#  4   country                  1500 non-null   object
#  5   cuisines                 1499 non-null   object
#  6   pickup_enabled           1500 non-null   bool
#  7   delivery_enabled         1500 non-null   bool
#  8   weighted_rating_value    1500 non-null   float64
#  9   aggregated_rating_count  1500 non-null   int64
# dtypes: bool(2), float64(1), int64(1), object(6)
# memory usage: 96.8+ KB

# %% [markdown]
# 由表格信息可知，该数据共1500条观察值，其中`cuisines`列存在缺失值

# %% [markdown]
# ### 评价缺失数据

# %% [markdown]
# 在了解`cuisines`存在缺失值后，找到缺失数据所在的观察值，并进行评估

# %%
original_data[original_data["cuisines"].isnull()]
# Out:
#              name               city state zipcode country cuisines  \
# 633  All You Need  Sunny Isles Beach    FL   33160      US      NaN
#
#      pickup_enabled  delivery_enabled  weighted_rating_value  \
# 633            True              True                    2.5
#
#      aggregated_rating_count
# 633                        2

# %% [markdown]
# 有一条数据存在缺失值
#
# 因为`cuisines`是菜系类型，所以该数据的缺失是在容许的范围内的

# %% [markdown]
# ### 评估重复数据

# %% [markdown]
# 由于该数据的列都没有唯一标识符，所以只有当所有列的数据相同时才是为重复数据

# %%
original_data.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1495    False
# 1496    False
# 1497     True
# 1498    False
# 1499     True
# Length: 1500, dtype: bool

# %%
original_data.duplicated().sum()
# Out:
# 618

# %% [markdown]
# 由图标可知该数据存在大量的重复数据，我猜测是由于数据采集时有多少次点评就把这么多条全部都放进去了

# %% [markdown]
# 下面进行验证
#
# 由上表可知第1497条和第1499条为重复数据，所以我们可以把其展示出来

# %%
original_data.iloc[1497]
# Out:
# name                                                                                                                                                                 Petro-Canada
# city                                                                                                                                                                    Longueuil
# state                                                                                                                                                                          QC
# zipcode                                                                                                                                                                       J4V
# country                                                                                                                                                                        CA
# cuisines                   Convenience, Everyday Essentials, Grocery, Home & Personal Care, Home &Amp; Personal Care, Nestle 4 Pour 2, Nestle Buy 2 Get 2, Offers, Offres, Snacks
# pickup_enabled                                                                                                                                                               True
# delivery_enabled                                                                                                                                                             True
# weighted_rating_value                                                                                                                                                         4.5
# aggregated_rating_count                                                                                                                                                        47
# Name: 1497, dtype: object

# %% [markdown]
# 将所有`name`为`Petro-Canada`,`city`为`Longueuil`展示出来

# %%
original_data[(original_data['name']=='Petro-Canada') & (original_data['city']=='Longueuil')]
# Out:
#               name       city state zipcode country  \
# 490   Petro-Canada  Longueuil    QC     J4V      CA
# 1249  Petro-Canada  Longueuil    QC     J4V      CA
# 1309  Petro-Canada  Longueuil    QC     J4V      CA
# 1497  Petro-Canada  Longueuil    QC     J4V      CA
#
#                                                                                                                                                     cuisines  \
# 490   Convenience, Everyday Essentials, Grocery, Home & Personal Care, Home &Amp; Personal Care, Nestle 4 Pour 2, Nestle Buy 2 Get 2, Offers, Offres, Snacks
# 1249  Convenience, Everyday Essentials, Grocery, Home & Personal Care, Home &Amp; Personal Care, Nestle 4 Pour 2, Nestle Buy 2 Get 2, Offers, Offres, Snacks
# 1309  Convenience, Everyday Essentials, Grocery, Home & Personal Care, Home &Amp; Personal Care, Nestle 4 Pour 2, Nestle Buy 2 Get 2, Offers, Offres, Snacks
# 1497  Convenience, Everyday Essentials, Grocery, Home & Personal Care, Home &Amp; Personal Care, Nestle 4 Pour 2, Nestle Buy 2 Get 2, Offers, Offres, Snacks
#
#       pickup_enabled  delivery_enabled  weighted_rating_value  \
# 490             True              True                    4.5
# 1249            True              True                    4.5
# 1309            True              True                    4.5
# 1497            True              True                    4.5
#
#       aggregated_rating_count
# 490                        47
# 1249                       47
# 1309                       47
# 1497                       47

# %% [markdown]
# 虽然，显然我的猜测是错误的，但是我们能发现重复数据是无意义且多余的数据，应该将其删除

# %% [markdown]
# ### 评价不一致数据

# %% [markdown]
# 不一致数据可能存在于`country`变量中，我们要查看是否存在多个不同值指代同一国家的情况。

# %% [markdown]
# 对于`country`变量

# %%
original_data["country"].value_counts()
# Out:
# country
# US    829
# CA    671
# Name: count, dtype: int64

# %% [markdown]
# 很显然不存在不一致数据

# %% [markdown]
# ### 评价无效或错误数据

# %% [markdown]
# 可以通过DataFrame的`describe`方法，对数值统计信息进行快速了解。

# %%
original_data.describe()
# Out:
#        weighted_rating_value  aggregated_rating_count
# count            1500.000000              1500.000000
# mean                3.724533                85.500667
# std                 0.989005               277.071136
# min                 1.000000                 1.000000
# 25%                 2.900000                 5.000000
# 50%                 4.100000                25.000000
# 75%                 4.600000                68.000000
# max                 5.000000              4211.000000

# %% [markdown]
# 由上表可知，数据全在可接受范围

# %% [markdown]
# 探寻`weighted_rating_value`是否都在0~5之间

# %%
original_data[(original_data["weighted_rating_value"]<0) & original_data["weighted_rating_value"]>5]
# Out:
# Empty DataFrame
# Columns: [name, city, state, zipcode, country, cuisines, pickup_enabled, delivery_enabled, weighted_rating_value, aggregated_rating_count]
# Index: []

# %% [markdown]
# 显然没有数据超出这个范围
#
# 所以该数据错误的数据

# %% [markdown]
# ## 清理数据

# %% [markdown]
# 根据前面评估部分得到的结论，我们需要进行的数据清理包括：
# - 将`cuisines`拆分
# - 删除重复数据

# %% [markdown]
# 为了区分开经过清理的数据和原始的数据，我们创建新的变量`cleaned_data`，让它为`original_data`复制出的副本。我们之后的清理步骤都将被运用在`cleaned_data`上。

# %%
cleaned_data = original_data.copy()
cleaned_data.head()
# Out:
#                              name         city state  zipcode country  \
# 0                     Burger King    Manitowoc    WI    54220      US
# 1                    Petro-Canada      Airdrie    AB      T4A      CA
# 2                        Boba Bae  Ashwaubenon    WI    54304      US
# 3            1001 Nights Shawarma    Kitchener    ON      N2C      CA
# 4  Chirpyhut Fried Chicken (JlgJ)     Richmond    BC  V6X 2B8      CA
#
#                                                                                                                                                                                                   cuisines  \
# 0                                                                                                                                    American, Burger, Burgers, Family Meals, Fast Food, Subs & Sandwiches
# 1  Ben & Jerry's, Café/Thé, Coffee/Tea, Convenience, Cool Treats, Crème Glacée, Crèmerie, Dessert, Desserts, Drinks, Dépanneur, Everyday Essentials, Food & Drinks, Fringales Nocturnes, Grocery, Gâter...
# 2                                                                                                                                                  American, Asian Food, Bubble Tea, Coffee & Tea, Dessert
# 3  Beau, Bon, Local, Chicken, Dessert, Desserts, Global Diversity Month, Lebanese, Local Goods, Mediterranean, Middle East, Middle Eastern, Mois Mondial De La Diversité, Moyen-Oriental, Must-Eat Rest...
# 4  Ailes, Allergy Friendly, American, Beau, Bon, Local, Burgers, Chicken, Fait-Maison, Fast Food, Group Friendly, Hamburgers, Homemade, Hot Deal Summer, Local Goods, Offers, Offres, Poulet, Promos D'...
#
#    pickup_enabled  delivery_enabled  weighted_rating_value  \
# 0            True              True                    2.4
# 1            True              True                    4.1
# 2            True              True                    4.0
# 3            True              True                    4.6
# 4            True              True                    4.6
#
#    aggregated_rating_count
# 0                       42
# 1                        1
# 2                       88
# 3                     1077
# 4                       30

# %% [markdown]
# 将`cuisines`拆分

# %%
cleaned_data['cuisines'] = cleaned_data['cuisines'].str.split(',')
cleaned_data = cleaned_data.explode('cuisines')
cleaned_data
# Out:
#              name           city state  zipcode country       cuisines  \
# 0     Burger King      Manitowoc    WI    54220      US       American
# 0     Burger King      Manitowoc    WI    54220      US         Burger
# 0     Burger King      Manitowoc    WI    54220      US        Burgers
# 0     Burger King      Manitowoc    WI    54220      US   Family Meals
# 0     Burger King      Manitowoc    WI    54220      US      Fast Food
# ...           ...            ...   ...      ...     ...            ...
# 1499   Bean House  Richmond Hill    ON  L4B 3Z1      CA        Noodles
# 1499   Bean House  Richmond Hill    ON  L4B 3Z1      CA          Vegan
# 1499   Bean House  Richmond Hill    ON  L4B 3Z1      CA     Vegetarian
# 1499   Bean House  Richmond Hill    ON  L4B 3Z1      CA     Végétalien
# 1499   Bean House  Richmond Hill    ON  L4B 3Z1      CA     Végétarien
#
#       pickup_enabled  delivery_enabled  weighted_rating_value  \
# 0               True              True                    2.4
# 0               True              True                    2.4
# 0               True              True                    2.4
# 0               True              True                    2.4
# 0               True              True                    2.4
# ...              ...               ...                    ...
# 1499            True              True                    4.8
# 1499            True              True                    4.8
# 1499            True              True                    4.8
# 1499            True              True                    4.8
# 1499            True              True                    4.8
#
#       aggregated_rating_count
# 0                          42
# 0                          42
# 0                          42
# 0                          42
# 0                          42
# ...                       ...
# 1499                       93
# 1499                       93
# 1499                       93
# 1499                       93
# 1499                       93
#
# [21522 rows x 10 columns]

# %% [markdown]
# 删除重复数据

# %%
cleaned_data = cleaned_data[~ cleaned_data.duplicated()]
cleaned_data
# Out:
#              name       city state zipcode country       cuisines  \
# 0     Burger King  Manitowoc    WI   54220      US       American
# 0     Burger King  Manitowoc    WI   54220      US         Burger
# 0     Burger King  Manitowoc    WI   54220      US        Burgers
# 0     Burger King  Manitowoc    WI   54220      US   Family Meals
# 0     Burger King  Manitowoc    WI   54220      US      Fast Food
# ...           ...        ...   ...     ...     ...            ...
# 1498      Denny's    Kingman    AZ   86401      US   Family Meals
# 1498      Denny's    Kingman    AZ   86401      US        Healthy
# 1498      Denny's    Kingman    AZ   86401      US         Salads
# 1498      Denny's    Kingman    AZ   86401      US       Sandwich
# 1498      Denny's    Kingman    AZ   86401      US          Steak
#
#       pickup_enabled  delivery_enabled  weighted_rating_value  \
# 0               True              True                    2.4
# 0               True              True                    2.4
# 0               True              True                    2.4
# 0               True              True                    2.4
# 0               True              True                    2.4
# ...              ...               ...                    ...
# 1498            True              True                    3.4
# 1498            True              True                    3.4
# 1498            True              True                    3.4
# 1498            True              True                    3.4
# 1498            True              True                    3.4
#
#       aggregated_rating_count
# 0                          42
# 0                          42
# 0                          42
# 0                          42
# 0                          42
# ...                       ...
# 1498                       22
# 1498                       22
# 1498                       22
# 1498                       22
# 1498                       22
#
# [9112 rows x 10 columns]

# %% [markdown]
# ## 保存清理后的数据

# %% [markdown]
# 完成数据清理后，把干净整齐的数据保存到新的文件里，文件名为`North America Restaurants_cleaned.csv`。

# %%
cleaned_data.to_csv("North America Restaurants_cleaned.csv",index= False)

# %%
pd.read_csv("North America Restaurants_cleaned.csv")
# Out:
#              name       city state zipcode country       cuisines  \
# 0     Burger King  Manitowoc    WI   54220      US       American
# 1     Burger King  Manitowoc    WI   54220      US         Burger
# 2     Burger King  Manitowoc    WI   54220      US        Burgers
# 3     Burger King  Manitowoc    WI   54220      US   Family Meals
# 4     Burger King  Manitowoc    WI   54220      US      Fast Food
# ...           ...        ...   ...     ...     ...            ...
# 9107      Denny's    Kingman    AZ   86401      US   Family Meals
# 9108      Denny's    Kingman    AZ   86401      US        Healthy
# 9109      Denny's    Kingman    AZ   86401      US         Salads
# 9110      Denny's    Kingman    AZ   86401      US       Sandwich
# 9111      Denny's    Kingman    AZ   86401      US          Steak
#
#       pickup_enabled  delivery_enabled  weighted_rating_value  \
# 0               True              True                    2.4
# 1               True              True                    2.4
# 2               True              True                    2.4
# 3               True              True                    2.4
# 4               True              True                    2.4
# ...              ...               ...                    ...
# 9107            True              True                    3.4
# 9108            True              True                    3.4
# 9109            True              True                    3.4
# 9110            True              True                    3.4
# 9111            True              True                    3.4
#
#       aggregated_rating_count
# 0                          42
# 1                          42
# 2                          42
# 3                          42
# 4                          42
# ...                       ...
# 9107                       22
# 9108                       22
# 9109                       22
# 9110                       22
# 9111                       22
#
# [9112 rows x 10 columns]
